# %% [markdown]
# <a href="https://colab.research.google.com/github/AdarkarRavaji2004/CodeAlpha_CreditScoringModel/blob/main/CodeAlpha_Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline

# Load a pre-trained speech emotion recognition model
classifier = pipeline(
    task="audio-classification",
    model="superb/wav2vec2-base-superb-er"
)

# Input audio file
audio_file = input("Enter the path of the audio file (.wav): ")

# Predict emotion
result = classifier(audio_file)

print("\nDetected Emotions:")
for item in result:
    print(f"{item['label']} : {item['score']:.4f}")

print("\nPredicted Emotion:", result[0]['label'])
# Out:
# Loading weights:   0%|          | 0/216 [00:00<?, ?it/s]
# Enter the path of the audio file (.wav): RAVDESS.wav
#
# Detected Emotions:
# neu : 0.5852
# hap : 0.3727
# ang : 0.0288
# sad : 0.0133
#
# Predicted Emotion: neu
